# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/dataset/data.zip /content
# !cp /content/gdrive/MyDrive/dataset/rsud20k.zip /content
# Out:
# Mounted at /content/gdrive

# %%
# !unzip -q /content/data.zip -d /content/full_dataset
# !unzip -q /content/rsud20k.zip -d /content/test_dataset

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 30.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install tflite-runtime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.5 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/kaggle/input/configuration/data.yaml model=yolo11n.pt epochs=70 imgsz=640 project=/kaggle/working name=runs
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo val model=/content/best_float32.tflite data=/content/data.yaml imgsz=320
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749565684.758865    5959 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749565684.766434    5959 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading /content/best_float32.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Setting batch=1 input of shape (1, 3, 320, 320)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 80.6±20.4 MB/s, size: 509.6 KB)
# ...

# %%
# !python /content/main.py
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/main.py", line 13, in <module>
#     model = Model(model_path=path_to_model)
#   File "/content/model.py", line 9, in __init__
#     self.interpreter = tflite.Interpreter(model_path=model_path)
#   File "/usr/local/lib/python3.11/dist-packages/tflite_runtime/interpreter.py", line 464, in __init__
#     self._interpreter = _interpreter_wrapper.CreateWrapperFromFile(
# AttributeError: _ARRAY_API not found
# ImportError: numpy.core.multiarray failed to import
#
# ...

# %%
# !yolo export model=/content/best.pt format=tflite imgsz=320 data=/content/data.yaml
